# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dirty_cafe_sales.csv')

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %% [markdown]
# #### Renaming Columns

# %%
old_column_names = df.columns.to_list()

# %%
old_column_names
# Out:
# ['Transaction ID',
#  'Item',
#  'Quantity',
#  'Price Per Unit',
#  'Total Spent',
#  'Payment Method',
#  'Location',
#  'Transaction Date']

# %%
new_column_names = []

# %%
for name in old_column_names:
    name = name.lower()
    name = name.replace(" ","_")
    new_column_names.append(name)

# %%
new_column_names
# Out:
# ['transaction_id',
#  'item',
#  'quantity',
#  'price_per_unit',
#  'total_spent',
#  'payment_method',
#  'location',
#  'transaction_date']

# %%
df.columns = new_column_names

# %%
df.head()
# Out:
#   transaction_id    item quantity price_per_unit total_spent  payment_method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    location transaction_date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    10000 non-null  object
#  1   item              9667 non-null   object
#  2   quantity          9862 non-null   object
#  3   price_per_unit    9821 non-null   object
#  4   total_spent       9827 non-null   object
#  5   payment_method    7421 non-null   object
#  6   location          6735 non-null   object
#  7   transaction_date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %% [markdown]
# #### Dropping all rows where  two of quantity, price_per_unit and total_spent are null

# %%
cols = ['quantity','price_per_unit','total_spent']

# %%
null_count = df[cols].isna().sum(axis=1)

# %%
df = df[null_count<2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    9994 non-null   object
#  1   item              9661 non-null   object
#  2   quantity          9860 non-null   object
#  3   price_per_unit    9818 non-null   object
#  4   total_spent       9826 non-null   object
#  5   payment_method    7417 non-null   object
#  6   location          6729 non-null   object
#  7   transaction_date  9835 non-null   object
# dtypes: object(8)
# memory usage: 702.7+ KB

# %% [markdown]
# #### Changing data types

# %%
df.head()
# Out:
#   transaction_id    item quantity price_per_unit total_spent  payment_method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    location transaction_date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df['quantity'] = pd.to_numeric(df['quantity'], errors='coerce')

# %%
df['price_per_unit'] = pd.to_numeric(df['price_per_unit'], errors='coerce')

# %%
df['total_spent'] = pd.to_numeric(df['total_spent'], errors='coerce')

# %%
df['transaction_date'] = pd.to_datetime(df['transaction_date'],errors='coerce')

# %%
df.head()
# Out:
#   transaction_id    item  quantity  price_per_unit  total_spent  \
# 0    TXN_1961373  Coffee       2.0             2.0          4.0
# 1    TXN_4977031    Cake       4.0             3.0         12.0
# 2    TXN_4271903  Cookie       4.0             1.0          NaN
# 3    TXN_7034554   Salad       2.0             5.0         10.0
# 4    TXN_3160411  Coffee       2.0             2.0          4.0
#
#    payment_method  location transaction_date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3         UNKNOWN   UNKNOWN       2023-04-27
# 4  Digital Wallet  In-store       2023-06-11

# %%
df.dtypes
# Out:
# transaction_id              object
# item                        object
# quantity                   float64
# price_per_unit             float64
# total_spent                float64
# payment_method              object
# location                    object
# transaction_date    datetime64[ns]
# dtype: object

# %% [markdown]
# #### Filling null values in item, price_per_unit and total_spent columns ( total_spent = quantity * price_per_unit)

# %%
df
# Out:
#      transaction_id      item  quantity  price_per_unit  total_spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          4.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401       NaN       3.0             1.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             1.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       payment_method  location transaction_date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [9994 rows x 8 columns]

# %%
df.loc[df['total_spent'].isna(), 'total_spent'] = (
    df['price_per_unit'] * df['quantity']
)

# %%
df.loc[df['price_per_unit'].isna(), 'price_per_unit'] = (
    df['total_spent'] / df['quantity']
)

# %%
df.loc[df['quantity'].isna(), 'quantity'] = (
    df['total_spent'] / df['price_per_unit']
)

# %% [markdown]
# #### Getting the price of each item and using it to fill NaN, Error and Unknown values

# %%
df.groupby('item')['price_per_unit'].first()
# Out:
# item
# Cake        3.0
# Coffee      2.0
# Cookie      1.0
# ERROR       1.5
# Juice       3.0
# Salad       5.0
# Sandwich    4.0
# Smoothie    4.0
# Tea         1.5
# UNKNOWN     3.0
# Name: price_per_unit, dtype: float64

# %% [markdown]
# #### Getting unique prices only

# %%
item_prices = {'Coffee':2.0,'Cookie':1.0,'Salad':5.0,'Tea':1.5}

# %%
for i in range (df.shape[0]):
    if pd.isna(df.iloc[i,1]) or df.iloc[i,1]=='ERROR' or df.iloc[i,1]=='UNKNOWN':
        for key,value in item_prices.items():
            if value == df.iloc[i,3]:
                df.iloc[i,1] = key

# %%
df
# Out:
#      transaction_id      item  quantity  price_per_unit  total_spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          4.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401    Cookie       3.0             1.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             1.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       payment_method  location transaction_date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# 2        Credit Card  In-store       2023-07-19
# 3            UNKNOWN   UNKNOWN       2023-04-27
# 4     Digital Wallet  In-store       2023-06-11
# ...              ...       ...              ...
# 9995             NaN   UNKNOWN       2023-08-30
# 9996  Digital Wallet       NaN       2023-06-02
# 9997  Digital Wallet       NaN       2023-03-02
# 9998  Digital Wallet       NaN       2023-12-02
# 9999            Cash  In-store       2023-11-07
#
# [9994 rows x 8 columns]

# %% [markdown]
# #### Replacing all unknown/error/null items with a standard value

# %%
for i in range(df.shape[0]):
    if pd.isna(df.iloc[i,1]) or df.iloc[i,1] == 'ERROR' or df.iloc[i,1] =='UNKNOWN':
        df.iloc[i,1] = 'Item Unknown'

# %%
df['payment_method'].unique()
# Out:
# array(['Credit Card', 'Cash', 'UNKNOWN', 'Digital Wallet', 'ERROR', nan],
#       dtype=object)

# %%
for i in range(df.shape[0]):
    if pd.isna(df.iloc[i,5]) or df.iloc[i,5] == 'ERROR' or df.iloc[i,5] =='UNKNOWN':
        df.iloc[i,5] = 'Payment Method Unknown'

# %%
df['location'].unique()
# Out:
# array(['Takeaway', 'In-store', 'UNKNOWN', nan, 'ERROR'], dtype=object)

# %%
for i in range(df.shape[0]):
    if pd.isna(df.iloc[i,6]) or df.iloc[i,6] == 'ERROR' or df.iloc[i,6] =='UNKNOWN':
        df.iloc[i,6] = 'Location Unknown'

# %%
df
# Out:
#      transaction_id      item  quantity  price_per_unit  total_spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          4.0
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401    Cookie       3.0             1.0          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             1.0          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#               payment_method          location transaction_date
# 0                Credit Card          Takeaway       2023-09-08
# 1                       Cash          In-store       2023-05-16
# 2                Credit Card          In-store       2023-07-19
# 3     Payment Method Unknown  Location Unknown       2023-04-27
# 4             Digital Wallet          In-store       2023-06-11
# ...                      ...               ...              ...
# 9995  Payment Method Unknown  Location Unknown       2023-08-30
# 9996          Digital Wallet  Location Unknown       2023-06-02
# 9997          Digital Wallet  Location Unknown       2023-03-02
# 9998          Digital Wallet  Location Unknown       2023-12-02
# 9999                    Cash          In-store       2023-11-07
#
# [9994 rows x 8 columns]

# %%
df[df['transaction_date'].isna()]
# Out:
#      transaction_id      item  quantity  price_per_unit  total_spent  \
# 11      TXN_3051279  Sandwich       2.0             4.0          8.0
# 29      TXN_7640952      Cake       4.0             3.0         12.0
# 33      TXN_7710508    Cookie       5.0             1.0          5.0
# 77      TXN_2091733     Salad       1.0             5.0          5.0
# 103     TXN_7028009      Cake       4.0             3.0         12.0
# ...             ...       ...       ...             ...          ...
# 9933    TXN_9460419      Cake       1.0             3.0          3.0
# 9937    TXN_8253472      Cake       1.0             3.0          3.0
# 9949    TXN_3130865     Juice       3.0             3.0          9.0
# 9983    TXN_9226047  Smoothie       3.0             4.0         12.0
# 9988    TXN_9594133      Cake       5.0             3.0         15.0
#
#               payment_method          location transaction_date
# 11               Credit Card          Takeaway              NaT
# 29            Digital Wallet          Takeaway              NaT
# 33                      Cash  Location Unknown              NaT
# 77    Payment Method Unknown          In-store              NaT
# 103   Payment Method Unknown          Takeaway              NaT
# ...                      ...               ...              ...
# 9933  Payment Method Unknown          Takeaway              NaT
# 9937  Payment Method Unknown  Location Unknown              NaT
# 9949  Payment Method Unknown          In-store              NaT
# 9983                    Cash  Location Unknown              NaT
# 9988  Payment Method Unknown  Location Unknown              NaT
#
# [460 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# transaction_id        0
# item                  0
# quantity             34
# price_per_unit       35
# total_spent          35
# payment_method        0
# location              0
# transaction_date    460
# dtype: int64

# %%
df[df['quantity'].isna()]
# Out:
#      transaction_id          item  quantity  price_per_unit  total_spent  \
# 236     TXN_8562645         Salad       NaN             5.0          NaN
# 278     TXN_3229409         Juice       NaN             3.0          NaN
# 629     TXN_9289174          Cake       NaN             NaN         12.0
# 641     TXN_2962976         Juice       NaN             3.0          NaN
# 738     TXN_8696094      Sandwich       NaN             4.0          NaN
# 1008    TXN_7225428           Tea       NaN             NaN          3.0
# 1436    TXN_7590801           Tea       NaN             NaN          6.0
# 1482    TXN_3593060      Smoothie       NaN             NaN         16.0
# 2330    TXN_3849488         Salad       NaN             NaN          5.0
# 2796    TXN_9188692          Cake       NaN             3.0          NaN
# 3203    TXN_4565754      Smoothie       NaN             4.0          NaN
# 3224    TXN_6297232        Coffee       NaN             2.0          NaN
# 3635    TXN_6177081        Cookie       NaN             NaN          1.0
# 3779    TXN_7376255  Item Unknown       NaN             NaN         25.0
# 4257    TXN_6470865        Coffee       NaN             2.0          NaN
# 5639    TXN_6206792           Tea       NaN             NaN          6.0
# 5841    TXN_5884081        Cookie       NaN             1.0          NaN
# 5845    TXN_8388462      Smoothie       NaN             NaN          8.0
# 6225    TXN_6859249        Cookie       NaN             NaN          2.0
# 6661    TXN_5308047        Cookie       NaN             NaN          1.0
# 6674    TXN_3071092        Coffee       NaN             NaN          4.0
# 7029    TXN_4628338        Coffee       NaN             2.0          NaN
# 7297    TXN_9944500      Smoothie       NaN             4.0          NaN
# 7597    TXN_1082717  Item Unknown       NaN             NaN          9.0
# 8021    TXN_2428781         Salad       NaN             5.0          NaN
# 8443    TXN_2023651      Sandwich       NaN             4.0          NaN
# 8465    TXN_9669616        Coffee       NaN             2.0          NaN
# 8574    TXN_2546684         Juice       NaN             3.0          NaN
# 8669    TXN_7764304          Cake       NaN             NaN          3.0
# 8975    TXN_8077367           Tea       NaN             NaN          7.5
# 9464    TXN_5744797          Cake       NaN             NaN          3.0
# 9590    TXN_9924732      Sandwich       NaN             4.0          NaN
# 9819    TXN_1208561  Item Unknown       NaN             NaN         20.0
# 9869    TXN_1975184        Coffee       NaN             2.0          NaN
#
#               payment_method          location transaction_date
# 236   Payment Method Unknown          In-store       2023-05-18
# 278                     Cash          Takeaway       2023-04-15
# 629           Digital Wallet          In-store       2023-12-30
# 641   Payment Method Unknown  Location Unknown       2023-03-17
# 738   Payment Method Unknown          Takeaway       2023-05-14
# 1008             Credit Card          Takeaway       2023-03-07
# 1436                    Cash          Takeaway              NaT
# 1482                    Cash  Location Unknown       2023-03-05
# 2330  Payment Method Unknown          In-store       2023-03-01
# 2796             Credit Card  Location Unknown       2023-12-01
# 3203          Digital Wallet          Takeaway       2023-10-06
# 3224  Payment Method Unknown  Location Unknown       2023-04-07
# 3635                    Cash  Location Unknown       2023-07-26
# 3779  Payment Method Unknown          In-store       2023-05-27
# 4257          Digital Wallet          Takeaway       2023-09-18
# 5639             Credit Card  Location Unknown       2023-10-13
# 5841          Digital Wallet          In-store       2023-07-05
# 5845  Payment Method Unknown          Takeaway       2023-08-19
# 6225  Payment Method Unknown  Location Unknown              NaT
# 6661             Credit Card  Location Unknown       2023-10-28
# 6674  Payment Method Unknown  Location Unknown       2023-09-08
# 7029                    Cash  Location Unknown       2023-12-25
# 7297                    Cash          In-store       2023-01-03
# 7597          Digital Wallet          In-store       2023-12-13
# 8021  Payment Method Unknown          In-store       2023-05-09
# 8443                    Cash          In-store       2023-05-25
# 8465  Payment Method Unknown  Location Unknown       2023-06-03
# 8574          Digital Wallet          Takeaway       2023-04-08
# 8669             Credit Card          Takeaway       2023-01-09
# 8975             Credit Card  Location Unknown       2023-02-27
# 9464                    Cash          In-store       2023-12-20
# 9590             Credit Card          In-store       2023-01-18
# 9819             Credit Card  Location Unknown       2023-08-19
# 9869          Digital Wallet  Location Unknown       2023-01-15

# %%
df = df.dropna()

# %%
df.to_csv('clean_sales_data.csv')
